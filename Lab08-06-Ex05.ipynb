// %% [markdown]
// # Lab 8 Exercise 5
//
// ## simple Method

// %% [markdown]
// 1. สร้าง console application project
//
// ```
//     dotnet new console --name Lab08_Ex05
// ```

// %% [markdown]
// 2. เปลี่ยน code ให้เป็นดังต่อไปนี้
//
// >  ```csharp
// >  1. var myObj = new MyClass();
// >  2. myObj.Info();
// >  3.
// >  4. class MyClass
// >  5. {
// >  6.     int F1;
// >  7.     string F2;
// >  8.     int F3 = 100;
// >  9.     string F4 = "ASDF";
// > 10.
// > 11.     public void Info()
// > 12.     {
// > 13.         System.Console.WriteLine($"Default integer      F1 = {F1}");  //Implicit fields initialization
// > 14.         System.Console.WriteLine($"Default string       F2 = {F2}");
// > 15.
// > 16.         System.Console.WriteLine($"Initialized integer  F3 = {F3}");  //Explicit field initialization
// > 17.         System.Console.WriteLine($"Initialized string   F4 = {F4}");
// > 18.     }
// > 19. }
// > ```

// %% [markdown]
// 3. Build project โดยการใช้คำสั่ง
//
// ```
//     dotnet build  Lab08_Ex05
// ```

// %% [markdown]
// 4. บันทึกผลที่ได้จากการรันคำสั่งในข้อ 3

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// ![image-2.png](attachment:image-2.png)

// %% [markdown]
// 5. Run project โดยการใช้คำสั่ง
//
// ```
//     dotnet run --project Lab08_Ex05
// ```

// %% [markdown]
// 6. บันทึกผลที่ได้จากการรันคำสั่งในข้อ 5

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// ![image-2.png](attachment:image-2.png)

// %% [markdown]
// 7. อธิบายสิ่งที่พบในการทดลอง

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// มีคำว่า Secceeded เมื่อรัน จะมีคำว่า
//
// Default integer      F1 = 0
//
// Default string       F2 =
//
// Initialized integer  F3 = 100
//
// Initialized string   F4 = ASDF

// %% [markdown]
// 8. นำ code ในข้อ 2 มารันบน polyglot notebook  โดยใส่ใน  code cell ด้านล่างนี้

// %%
var myObj = new MyClass();
myObj.Info();

class MyClass
{
    int F1;
    string F2;
    int F3 = 100;
    string F4 = "ASDF";

    public void Info()
    {
        System.Console.WriteLine($"Default integer      F1 = {F1}");  //Implicit fields initialization
        System.Console.WriteLine($"Default string       F2 = {F2}");
        System.Console.WriteLine($"Initialized integer  F3 = {F3}");  //Explicit field initialization
        System.Console.WriteLine($"Initialized string   F4 = {F4}");
    } 
}

// %% [markdown]
// 8.1 ผลการรันเป็นอย่างไร

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// Default integer      F1 = 0
//
//
// Default string       F2 =
//
//
// Initialized integer  F3 = 100
//
//
// Initialized string   F4 = ASDF

// %% [markdown]
// 8.2 เหมือนหรือต่างจาก console application อย่างไร

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// เหมือนกัน ทั้งสองส่วน notebook ขึ้นดังนี้
//
// Default integer      F1 = 0
//
//
// Default string       F2 =
//
//
// Initialized integer  F3 = 100
//
//
// Initialized string   F4 = ASDF

// %% [markdown]
// ## คำถาม

// %% [markdown]
// 1. ถ้าแก้ไขโค้ดในบรรทัดที่ 11 เป็นดังต่อไปนี้  จะได้ผลการ build หรือ run เป็นอย่างไร ให้แสดง output ที่โปรแกรมแสดงออกมา
// ```csharp
//     void Info()
// ```

// %%
var myObj = new MyClass();
myObj.Info();

class MyClass
{
    int F1;
    string F2;
    int F3 = 100;
    string F4 = "ASDF";

    void Info()
    {
        System.Console.WriteLine($"Default integer      F1 = {F1}");  //Implicit fields initialization
        System.Console.WriteLine($"Default string       F2 = {F2}");
        System.Console.WriteLine($"Initialized integer  F3 = {F3}");  //Explicit field initialization
        System.Console.WriteLine($"Initialized string   F4 = {F4}");
    } 
}

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// Error: (2,7): error CS0122: 'MyClass.Info()' is inaccessible due to its protection level

// %% [markdown]
// 2. ถ้าแก้ไขโค้ดในบรรทัดที่ 14 เป็นดังต่อไปนี้  จะได้ผลการ build หรือ run เป็นอย่างไร ให้แสดง output ที่โปรแกรมแสดงออกมา
// ```csharp
//     private void Info()
// ```

// %%
var myObj = new MyClass();
myObj.Info();

class MyClass
{
    int F1;
    string F2;
    int F3 = 100;
    string F4 = "ASDF";

    public void Info()
    {
        System.Console.WriteLine($"Default integer      F1 = {F1}");  //Implicit fields initialization
        private void Info()
        System.Console.WriteLine($"Initialized integer  F3 = {F3}");  //Explicit field initialization
        System.Console.WriteLine($"Initialized string   F4 = {F4}");
    } 
}

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// Error: (13,69): error CS1513: } expected
// (14,28): error CS1002: ; expected
// (15,33): error CS1519: Invalid token '(' in class, record, struct, or interface member declaration
// (15,34): error CS1031: Type expected
// (15,34): error CS8124: Tuple must contain at least two elements.
// (15,34): error CS1026: ) expected
// (15,34): error CS1519: Invalid token '$"Initialized integer F3 = {F3}"' in class, record, struct, or interface member declaration
// (16,33): error CS1519: Invalid token '(' in class, record, struct, or interface member declaration
// (16,34): error CS1031: Type expected
// (16,34): error CS8124: Tuple must contain at least two elements.
// (16,34): error CS1026: ) expected
// (16,34): error CS1519: Invalid token '$"Initialized string F4 = {F4}"' in class, record, struct, or interface member declaration
// (18,1): error CS7017: Member definition, statement, or end-of-file expected
